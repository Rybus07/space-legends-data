# %% [markdown]
# ### DSCI 511 Term Project: Mission Parameters Extraction
#
# **Author:** Phillip Roman
#
# **Purpose:** Extract and clean mission-related attributes from raw launch data
#
# **Date:** November 2025
#
# ---
#
# This notebook extracts 10 key mission attributes from the Launch Library 2 API dataset and exports them as a clean TSV file for merging.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Import Modules

# %%
import json
import pandas as pd
import csv
from pprint import pprint

# %% [markdown]
# ##Load Raw Data File
#
# Loading the big file `raw_baseline_launches_Phillip.json` from my Google Drive.
#
# I'm wrapping the file-opening part in a `try...except` to handle any errors. Also using `.get('launches', [])` to safely extract the launches list from the JSON structure - gives an empty list if the 'launches' key isn't found.
#
# **Note:** Currently processing the most recent 50 launches for sample testing. USE_SAMPLE flag can be toggled False for full dataset.

# %%
try:
    with open('/content/drive/MyDrive/DSCI511/Term Project/raw_baseline_launches_Phillip.json', 'r', encoding='utf-8') as f:
        full_data = json.load(f)
except FileNotFoundError:
    print("ERROR: raw_baseline_launches.json not found.")
    exit()

# list of all launches is inside the 'launches' key
all_launches = full_data.get('launches', [])
print(f"Loaded {len(all_launches)} total launches.")

USE_SAMPLE = False

if USE_SAMPLE:
    data_source = all_launches[-50:] # Sample last 50
else:
    data_source = all_launches # Full dataset

print(f"Processing {len(data_source)} launches...")
# Out:
# Loaded 7333 total launches.
# Processing 7333 launches...

# %% [markdown]
# ## Data Reconnaissance
# Quick peek at the first launch record to see what keys are available

# %%
# print the first launch in the sample to see all the keys
pprint(data_source[0])
# Out:
# {'agency_launch_attempt_count': 1,
#  'agency_launch_attempt_count_year': 1,
#  'failreason': '',
#  'flightclub_url': None,
#  'hashtag': None,
#  'id': 'e3df2ecd-c239-472f-95e4-2b89b4f75800',
#  'image': {'credit': None,
#            'id': 1844,
#            'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/sputnik_8k74ps_image_20210830185541.jpg',
#            'license': {'id': 1, 'link': None, 'name': 'Unknown', 'priority': 9},
#            'name': '[AUTO] Sputnik 8K74PS - image',
#            'single_use': True,
#            'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305193923.jpeg',
#            'variants': []},
#  'info_urls': [],
#  'infographic': None,
#  'last_updated': '2024-03-17T19:17:35Z',
#  'launch_designator': '1957-001',
#  'launch_service_provider': {'abbrev': 'CCCP',
#                              'administrator': None,
#                              'attempted_landings': 0,
#                              'attempted_landings_payload': 3,
#                              'attempted_landings_spacecraft': 0,
#                              'consecutive_successful_landings': 0,
#                              'consecutive_successful_launches': 17,
#                              'country': [{'alpha_2_code': 'RU',
#                                           'alpha_3_code': 'RUS',
#                                           'id': 5,
#                                           'name': 'Russia',
#                                           'nationality_name': 'Russian',
#                                           'nationality_name_composed': 'Russo'}],
#                              'description': 'The Soviet space program, was the '
#                                             'national space program of the '
#                                             'Union of Soviet Socialist '
#                                             'Republics (USSR) actived from '
#                                             '1930s until disintegration of the '
#                                             'Soviet Union in 1991.\r\n'
#                                             '\r\n'
#                                             "The Soviet Union's space program "
#                                             'was mainly based on the '
#                                             'cosmonautic exploration of space '
#                                             'and the development of the '
#                                             'expandable launch vehicles, which '
#                                             'had been split between many '
#                                             'design bureaus competing against '
#                                             'each other. Over its 60-years of '
#                                             'history, the Russian program was '
#                                             'responsible for a number of '
#                                             'pioneering feats and '
#                                             'accomplishments in the human '
#                                             'space flight, including the first '
#                                             'intercontinental ballistic '
#                                             'missile (R-7), first satellite '
#                                             '(Sputnik 1), first animal in '
#                                             'Earth orbit (the dog Laika on '
#                                             'Sputnik 2), first human in space '
#                                             'and Earth orbit (cosmonaut Yuri '
#                                             'Gagarin on Vostok 1), first woman '
#                                             'in space and Earth orbit '
#                                             '(cosmonaut Valentina Tereshkova '
#                                             'on Vostok 6), first spacewalk '
#                                             '(cosmonaut Alexei Leonov on '
#                                             'Voskhod 2), first Moon impact '
#                                             '(Luna 2), first image of the far '
#                                             'side of the Moon (Luna 3) and '
#                                             'unmanned lunar soft landing (Luna '
#                                             '9), first space rover (Lunokhod '
#                                             '1), first sample of lunar soil '
#                                             'automatically extracted and '
#                                             'brought to Earth (Luna 16), and '
#                                             'first space station (Salyut 1). '
#                                             'Further notable records included '
#                                             'the first interplanetary probes: '
#                                             'Venera 1 and Mars 1 to fly by '
#                                             'Venus and Mars, respectively, '
#                                             'Venera 3 and Mars 2 to impact the '
#                                             'respective planet surface, and '
#                                             'Venera 7 and Mars 3 to make soft '
#                                             'landings on these planets.',
#                              'failed_landings': 0,
#                              'failed_landings_payload': 0,
#                              'failed_landings_spacecraft': 0,
#                              'failed_launches': 168,
#                              'featured': False,
#                              'founding_year': 1931,
#                              'id': 66,
#                              'image': {'credit': None,
#                                        'id': 28,
#                                        'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet2520space2520program_image_20191229081306.jpeg',
#                                        'license': {'id': 1,
#                                                    'link': None,
#                                                    'name': 'Unknown',
#                                                    'priority': 9},
#                                        'name': '[AUTO] Soviet Space Program - '
#                                                'image',
#                                        'single_use': True,
#                                        'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305184701.jpeg',
#                                        'variants': []},
#                              'info_url': None,
#                              'launchers': '',
#                              'logo': {'credit': 'USSR',
#                                       'id': 182,
#                                       'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet2520space2520program_logo_20191229081307.png',
#                                       'license': {'id': 1,
#                                                   'link': None,
#                                                   'name': 'Unknown',
#                                                   'priority': 9},
#                                       'name': 'Soviet Space Program logo',
#                                       'single_use': True,
#                                       'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185129.png',
#                                       'variants': []},
#                              'name': 'Soviet Space Program',
#                              'parent': None,
#                              'pending_launches': 0,
#                              'response_mode': 'normal',
#                              'social_logo': {'credit': 'USSR',
#                                              'id': 92,
#                                              'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet_space_pr_image_20251017113333.png',
#                                              'license': {'id': 1,
#                                                          'link': None,
#                                                          'name': 'Unknown',
#                                                          'priority': 9},
#                                              'name': 'Soviet Space Program '
#                                                      'social logo',
#                                              'single_use': True,
#                                              'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet_space_pr_image_thumbnail_20251017113333.png',
#                                              'variants': []},
#                              'social_media_links': [],
#                              'spacecraft': '',
#                              'successful_landings': 0,
#                              'successful_landings_payload': 3,
#                              'successful_landings_spacecraft': 0,
#                              'successful_launches': 2288,
#                              'total_launch_count': 2456,
#                              'type': {'id': 1, 'name': 'Government'},
#                              'url': 'https://ll.thespacedevs.com/2.3.0/agencies/66/',
#                              'wiki_url': 'https://en.wikipedia.org/wiki/Soviet_space_program'},
#  'location_launch_attempt_count': 1,
#  'location_launch_attempt_count_year': 1,
#  'mission': {'agencies': [],
#              'description': 'First artificial satellite consisting of a 58 cm '
#                             'pressurized aluminium shell containing two 1 W '
#                             'transmitters for a total mass of 83.6 kg.',
#              'id': 1430,
#              'image': None,
#              'info_urls': [],
#              'name': 'Sputnik 1',
#              'orbit': {'abbrev': 'LEO',
#                        'celestial_body': {'id': 1,
#                                           'name': 'Earth',
#                                           'response_mode': 'list'},
#                        'id': 8,
#                        'name': 'Low Earth Orbit'},
#              'type': 'Test Flight',
#              'vid_urls': []},
#  'mission_patches': [],
#  'name': 'Sputnik 8K74PS | Sputnik 1',
#  'net': '1957-10-04T19:28:34Z',
#  'net_precision': None,
#  'orbital_launch_attempt_count': 1,
#  'orbital_launch_attempt_count_year': 1,
#  'pad': {'active': True,
#          'agencies': [],
#          'country': {'alpha_2_code': 'KZ',
#                      'alpha_3_code': 'KAZ',
#                      'id': 44,
#                      'name': 'Kazakhstan',
#                      'nationality_name': 'Kazakh',
#                      'nationality_name_composed': 'Kazakhstani'},
#          'description': None,
#          'fastest_turnaround': 'PT23H32M33S',
#          'id': 32,
#          'image': None,
#          'info_url': None,
#          'latitude': 45.92,
#          'location': {'active': True,
#                       'celestial_body': {'atmosphere': True,
#                                          'description': 'Earth is the third '
#                                                         'planet from the Sun '
#                                                         'and the only '
#                                                         'astronomical object '
#                                                         'known to harbor life.',
#                                          'diameter': 12742000.0,
#                                          'failed_landings': 45,
#                                          'failed_launches': 547,
#                                          'gravity': 9.80655,
#                                          'id': 1,
#                                          'image': {'credit': 'NASA',
#                                                    'id': 2040,
#                                                    'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/earth_2528apol_image_20240402194304.jpeg',
#                                                    'license': {'id': 4,
#                                                                'link': 'https://www.nasa.gov/nasa-brand-center/images-and-media/',
#                                                                'name': 'NASA '
#                                                                        'Image '
#                                                                        'and '
#                                                                        'Media '
#                                                                        'Guidelines',
#                                                                'priority': 0},
#                                                    'name': 'Earth (Apollo 17)',
#                                                    'single_use': True,
#                                                    'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/earth_2528apol_image_thumbnail_20240402194305.jpeg',
#                                                    'variants': []},
#                                          'length_of_day': '1 00:00:00',
#                                          'mass': 5.972168e+24,
#                                          'name': 'Earth',
#                                          'response_mode': 'normal',
#                                          'successful_landings': 1166,
#                                          'successful_launches': 6775,
#                                          'total_attempted_landings': 1211,
#                                          'total_attempted_launches': 7322,
#                                          'type': {'id': 1, 'name': 'Planet'},
#                                          'wiki_url': 'https://en.wikipedia.org/wiki/Earth'},
#                       'country': {'alpha_2_code': 'KZ',
#                                   'alpha_3_code': 'KAZ',
#                                   'id': 44,
#                                   'name': 'Kazakhstan',
#                                   'nationality_name': 'Kazakh',
#                                   'nationality_name_composed': 'Kazakhstani'},
#                       'description': 'The Baikonur Cosmodrome is a spaceport '
#                                      'operated by Russia within Kazakhstan. '
#                                      'Located in the Kazakh city of Baikonur, '
#                                      'it is the largest operational space '
#                                      'launch facility in terms of area. All '
#                                      'Russian crewed spaceflights are launched '
#                                      'from Baikonur.',
#                       'id': 15,
#                       'image': {'credit': 'NASA/Bill Ingalls',
#                                 'id': 2198,
#                                 'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soyuz_launch_pa_image_20240918150530.jpg',
#                                 'license': {'id': 4,
#                                             'link': 'https://www.nasa.gov/nasa-brand-center/images-and-media/',
#                                             'name': 'NASA Image and Media '
#                                                     'Guidelines',
#                                             'priority': 0},
#                                 'name': 'Soyuz launch pad at the Baikonur '
#                                         'Cosmodrome',
#                                 'single_use': True,
#                                 'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soyuz_launch_pa_image_thumbnail_20240918150530.jpeg',
#                                 'variants': []},
#                       'latitude': 45.965,
#                       'longitude': 63.305,
#                       'map_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/location_15_20200803142517.jpg',
#                       'name': 'Baikonur Cosmodrome, Republic of Kazakhstan',
#                       'response_mode': 'normal',
#                       'timezone_name': 'Asia/Qyzylorda',
#                       'total_landing_count': 0,
#                       'total_launch_count': 1558,
#                       'url': 'https://ll.thespacedevs.com/2.3.0/locations/15/'},
#          'longitude': 63.342,
#          'map_image': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/map_images/pad_32_20200803143513.jpg',
#          'map_url': 'https://www.google.com/maps?q=45.92,63.342',
#          'name': '1/5',
#          'orbital_launch_attempt_count': 487,
#          'total_launch_count': 487,
#          'url': 'https://ll.thespacedevs.com/2.3.0/pads/32/',
#          'wiki_url': ''},
#  'pad_launch_attempt_count': 1,
#  'pad_launch_attempt_count_year': 1,
#  'pad_turnaround': 'P0D',
#  'probability': None,
#  'program': [],
#  'response_mode': 'detailed',
#  'rocket': {'configuration': {'active': False,
#                               'alias': '',
#                               'apogee': None,
#                               'attempted_landings': 0,
#                               'consecutive_successful_landings': 0,
#                               'consecutive_successful_launches': 2,
#                               'description': 'An early Russian rocket designed '
#                                              'by Sergei Korolev in the Soviet '
#                                              'Union',
#                               'diameter': None,
#                               'failed_landings': 0,
#                               'failed_launches': 0,
#                               'families': [{'active': False,
#                                             'attempted_landings': 0,
#                                             'consecutive_successful_landings': 0,
#                                             'consecutive_successful_launches': 3,
#                                             'description': '',
#                                             'failed_landings': 0,
#                                             'failed_launches': 1,
#                                             'id': 154,
#                                             'maiden_flight': '1957-10-04',
#                                             'manufacturer': [{'abbrev': 'OKB-1',
#                                                               'administrator': None,
#                                                               'attempted_landings': 0,
#                                                               'attempted_landings_payload': 0,
#                                                               'attempted_landings_spacecraft': 0,
#                                                               'consecutive_successful_landings': 0,
#                                                               'consecutive_successful_launches': 0,
#                                                               'country': [{'alpha_2_code': 'RU',
#                                                                            'alpha_3_code': 'RUS',
#                                                                            'id': 5,
#                                                                            'name': 'Russia',
#                                                                            'nationality_name': 'Russian',
#                                                                            'nationality_name_composed': 'Russo'}],
#                                                               'description': None,
#                                                               'failed_landings': 0,
#                                                               'failed_landings_payload': 0,
#                                                               'failed_landings_spacecraft': 0,
#                                                               'failed_launches': 0,
#                                                               'featured': False,
#                                                               'founding_year': 1946,
#                                                               'id': 1000,
#                                                               'image': None,
#                                                               'info_url': None,
#                                                               'launchers': '',
#                                                               'logo': None,
#                                                               'name': 'Energia',
#                                                               'parent': None,
#                                                               'pending_launches': 0,
#                                                               'response_mode': 'normal',
#                                                               'social_logo': None,
#                                                               'social_media_links': [],
#                                                               'spacecraft': '',
#                                                               'successful_landings': 0,
#                                                               'successful_landings_payload': 0,
#                                                               'successful_landings_spacecraft': 0,
#                                                               'successful_launches': 0,
#                                                               'total_launch_count': 0,
#                                                               'type': {'id': 1,
#                                                                        'name': 'Government'},
#                                                               'url': 'https://ll.thespacedevs.com/2.3.0/agencies/1000/',
#                                                               'wiki_url': 'https://en.wikipedia.org/wiki/Energia_(corporation)'}],
#                                             'name': 'Sputnik',
#                                             'parent': None,
#                                             'pending_launches': 0,
#                                             'response_mode': 'detailed',
#                                             'successful_landings': 0,
#                                             'successful_launches': 5,
#                                             'total_launch_count': 6}],
#                               'fastest_turnaround': 'P29DT7H1M26S',
#                               'full_name': 'Sputnik 8K74PS',
#                               'geo_capacity': None,
#                               'gto_capacity': None,
#                               'id': 468,
#                               'image': {'credit': None,
#                                         'id': 1844,
#                                         'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/sputnik_8k74ps_image_20210830185541.jpg',
#                                         'license': {'id': 1,
#                                                     'link': None,
#                                                     'name': 'Unknown',
#                                                     'priority': 9},
#                                         'name': '[AUTO] Sputnik 8K74PS - image',
#                                         'single_use': True,
#                                         'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305193923.jpeg',
#                                         'variants': []},
#                               'info_url': None,
#                               'is_placeholder': False,
#                               'launch_cost': None,
#                               'launch_mass': None,
#                               'length': None,
#                               'leo_capacity': None,
#                               'maiden_flight': '1957-10-04',
#                               'manufacturer': {'abbrev': 'OKB-1',
#                                                'administrator': None,
#                                                'attempted_landings': 0,
#                                                'attempted_landings_payload': 0,
#                                                'attempted_landings_spacecraft': 0,
#                                                'consecutive_successful_landings': 0,
#                                                'consecutive_successful_launches': 0,
#                                                'country': [{'alpha_2_code': 'RU',
#                                                             'alpha_3_code': 'RUS',
#                                                             'id': 5,
#                                                             'name': 'Russia',
#                                                             'nationality_name': 'Russian',
#                                                             'nationality_name_composed': 'Russo'}],
#                                                'description': None,
#                                                'failed_landings': 0,
#                                                'failed_landings_payload': 0,
#                                                'failed_landings_spacecraft': 0,
#                                                'failed_launches': 0,
#                                                'featured': False,
#                                                'founding_year': 1946,
#                                                'id': 1000,
#                                                'image': None,
#                                                'info_url': None,
#                                                'launchers': '',
#                                                'logo': None,
#                                                'name': 'Energia',
#                                                'parent': None,
#                                                'pending_launches': 0,
#                                                'response_mode': 'normal',
#                                                'social_logo': None,
#                                                'social_media_links': [],
#                                                'spacecraft': '',
#                                                'successful_landings': 0,
#                                                'successful_landings_payload': 0,
#                                                'successful_landings_spacecraft': 0,
#                                                'successful_launches': 0,
#                                                'total_launch_count': 0,
#                                                'type': {'id': 1,
#                                                         'name': 'Government'},
#                                                'url': 'https://ll.thespacedevs.com/2.3.0/agencies/1000/',
#                                                'wiki_url': 'https://en.wikipedia.org/wiki/Energia_(corporation)'},
#                               'max_stage': 1,
#                               'min_stage': 1,
#                               'name': 'Sputnik 8K74PS',
#                               'pending_launches': 0,
#                               'program': [],
#                               'response_mode': 'detailed',
#                               'reusable': False,
#                               'sso_capacity': None,
#                               'successful_landings': 0,
#                               'successful_launches': 2,
#                               'to_thrust': None,
#                               'total_launch_count': 2,
#                               'url': 'https://ll.thespacedevs.com/2.3.0/launcher_configurations/468/',
#                               'variant': '8K74PS',
#                               'wiki_url': None},
#             'id': 3003,
#             'launcher_stage': [],
#             'payloads': [{'amount': 1,
#                           'destination': 'Orbit',
#                           'docking_events': [],
#                           'id': 5,
#                           'landing': None,
#                           'payload': {'cost': None,
#                                       'description': 'Sputnik 1 was the first '
#                                                      'artificial Earth '
#                                                      'satellite.',
#                                       'id': 5,
#                                       'image': {'credit': 'Andrey Butko',
#                                                 'id': 2015,
#                                                 'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/sputnik_1_repli_image_20240317191145.jpeg',
#                                                 'license': {'id': 21,
#                                                             'link': 'https://creativecommons.org/licenses/by-sa/3.0/deed.en',
#                                                             'name': 'CC BY-SA '
#                                                                     '3.0',
#                                                             'priority': 4},
#                                                 'name': 'Sputnik 1 replica',
#                                                 'single_use': True,
#                                                 'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/sputnik_1_repli_image_thumbnail_20240317191145.jpeg',
#                                                 'variants': []},
#                                       'info_link': '',
#                                       'manufacturer': {'abbrev': 'OKB-1',
#                                                        'administrator': None,
#                                                        'attempted_landings': 0,
#                                                        'attempted_landings_payload': 0,
#                                                        'attempted_landings_spacecraft': 0,
#                                                        'consecutive_successful_landings': 0,
#                                                        'consecutive_successful_launches': 0,
#                                                        'country': [{'alpha_2_code': 'RU',
#                                                                     'alpha_3_code': 'RUS',
#                                                                     'id': 5,
#                                                                     'name': 'Russia',
#                                                                     'nationality_name': 'Russian',
#                                                                     'nationality_name_composed': 'Russo'}],
#                                                        'description': None,
#                                                        'failed_landings': 0,
#                                                        'failed_landings_payload': 0,
#                                                        'failed_landings_spacecraft': 0,
#                                                        'failed_launches': 0,
#                                                        'featured': False,
#                                                        'founding_year': 1946,
#                                                        'id': 1000,
#                                                        'image': None,
#                                                        'info_url': None,
#                                                        'launchers': '',
#                                                        'logo': None,
#                                                        'name': 'Energia',
#                                                        'parent': None,
#                                                        'pending_launches': 0,
#                                                        'response_mode': 'normal',
#                                                        'social_logo': None,
#                                                        'social_media_links': [],
#                                                        'spacecraft': '',
#                                                        'successful_landings': 0,
#                                                        'successful_landings_payload': 0,
#                                                        'successful_landings_spacecraft': 0,
#                                                        'successful_launches': 0,
#                                                        'total_launch_count': 0,
#                                                        'type': {'id': 1,
#                                                                 'name': 'Government'},
#                                                        'url': 'https://ll.thespacedevs.com/2.3.0/agencies/1000/',
#                                                        'wiki_url': 'https://en.wikipedia.org/wiki/Energia_(corporation)'},
#                                       'mass': 84.0,
#                                       'name': 'Sputnik 1',
#                                       'operator': {'abbrev': 'CCCP',
#                                                    'administrator': None,
#                                                    'attempted_landings': 0,
#                                                    'attempted_landings_payload': 3,
#                                                    'attempted_landings_spacecraft': 0,
#                                                    'consecutive_successful_landings': 0,
#                                                    'consecutive_successful_launches': 17,
#                                                    'country': [{'alpha_2_code': 'RU',
#                                                                 'alpha_3_code': 'RUS',
#                                                                 'id': 5,
#                                                                 'name': 'Russia',
#                                                                 'nationality_name': 'Russian',
#                                                                 'nationality_name_composed': 'Russo'}],
#                                                    'description': 'The Soviet '
#                                                                   'space '
#                                                                   'program, '
#                                                                   'was the '
#                                                                   'national '
#                                                                   'space '
#                                                                   'program of '
#                                                                   'the Union '
#                                                                   'of Soviet '
#                                                                   'Socialist '
#                                                                   'Republics '
#                                                                   '(USSR) '
#                                                                   'actived '
#                                                                   'from 1930s '
#                                                                   'until '
#                                                                   'disintegration '
#                                                                   'of the '
#                                                                   'Soviet '
#                                                                   'Union in '
#                                                                   '1991.\r\n'
#                                                                   '\r\n'
#                                                                   'The Soviet '
#                                                                   "Union's "
#                                                                   'space '
#                                                                   'program was '
#                                                                   'mainly '
#                                                                   'based on '
#                                                                   'the '
#                                                                   'cosmonautic '
#                                                                   'exploration '
#                                                                   'of space '
#                                                                   'and the '
#                                                                   'development '
#                                                                   'of the '
#                                                                   'expandable '
#                                                                   'launch '
#                                                                   'vehicles, '
#                                                                   'which had '
#                                                                   'been split '
#                                                                   'between '
#                                                                   'many design '
#                                                                   'bureaus '
#                                                                   'competing '
#                                                                   'against '
#                                                                   'each other. '
#                                                                   'Over its '
#                                                                   '60-years of '
#                                                                   'history, '
#                                                                   'the Russian '
#                                                                   'program was '
#                                                                   'responsible '
#                                                                   'for a '
#                                                                   'number of '
#                                                                   'pioneering '
#                                                                   'feats and '
#                                                                   'accomplishments '
#                                                                   'in the '
#                                                                   'human space '
#                                                                   'flight, '
#                                                                   'including '
#                                                                   'the first '
#                                                                   'intercontinental '
#                                                                   'ballistic '
#                                                                   'missile '
#                                                                   '(R-7), '
#                                                                   'first '
#                                                                   'satellite '
#                                                                   '(Sputnik '
#                                                                   '1), first '
#                                                                   'animal in '
#                                                                   'Earth orbit '
#                                                                   '(the dog '
#                                                                   'Laika on '
#                                                                   'Sputnik 2), '
#                                                                   'first human '
#                                                                   'in space '
#                                                                   'and Earth '
#                                                                   'orbit '
#                                                                   '(cosmonaut '
#                                                                   'Yuri '
#                                                                   'Gagarin on '
#                                                                   'Vostok 1), '
#                                                                   'first woman '
#                                                                   'in space '
#                                                                   'and Earth '
#                                                                   'orbit '
#                                                                   '(cosmonaut '
#                                                                   'Valentina '
#                                                                   'Tereshkova '
#                                                                   'on Vostok '
#                                                                   '6), first '
#                                                                   'spacewalk '
#                                                                   '(cosmonaut '
#                                                                   'Alexei '
#                                                                   'Leonov on '
#                                                                   'Voskhod 2), '
#                                                                   'first Moon '
#                                                                   'impact '
#                                                                   '(Luna 2), '
#                                                                   'first image '
#                                                                   'of the far '
#                                                                   'side of the '
#                                                                   'Moon (Luna '
#                                                                   '3) and '
#                                                                   'unmanned '
#                                                                   'lunar soft '
#                                                                   'landing '
#                                                                   '(Luna 9), '
#                                                                   'first space '
#                                                                   'rover '
#                                                                   '(Lunokhod '
#                                                                   '1), first '
#                                                                   'sample of '
#                                                                   'lunar soil '
#                                                                   'automatically '
#                                                                   'extracted '
#                                                                   'and brought '
#                                                                   'to Earth '
#                                                                   '(Luna 16), '
#                                                                   'and first '
#                                                                   'space '
#                                                                   'station '
#                                                                   '(Salyut 1). '
#                                                                   'Further '
#                                                                   'notable '
#                                                                   'records '
#                                                                   'included '
#                                                                   'the first '
#                                                                   'interplanetary '
#                                                                   'probes: '
#                                                                   'Venera 1 '
#                                                                   'and Mars 1 '
#                                                                   'to fly by '
#                                                                   'Venus and '
#                                                                   'Mars, '
#                                                                   'respectively, '
#                                                                   'Venera 3 '
#                                                                   'and Mars 2 '
#                                                                   'to impact '
#                                                                   'the '
#                                                                   'respective '
#                                                                   'planet '
#                                                                   'surface, '
#                                                                   'and Venera '
#                                                                   '7 and Mars '
#                                                                   '3 to make '
#                                                                   'soft '
#                                                                   'landings on '
#                                                                   'these '
#                                                                   'planets.',
#                                                    'failed_landings': 0,
#                                                    'failed_landings_payload': 0,
#                                                    'failed_landings_spacecraft': 0,
#                                                    'failed_launches': 168,
#                                                    'featured': False,
#                                                    'founding_year': 1931,
#                                                    'id': 66,
#                                                    'image': {'credit': None,
#                                                              'id': 28,
#                                                              'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet2520space2520program_image_20191229081306.jpeg',
#                                                              'license': {'id': 1,
#                                                                          'link': None,
#                                                                          'name': 'Unknown',
#                                                                          'priority': 9},
#                                                              'name': '[AUTO] '
#                                                                      'Soviet '
#                                                                      'Space '
#                                                                      'Program '
#                                                                      '- image',
#                                                              'single_use': True,
#                                                              'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305184701.jpeg',
#                                                              'variants': []},
#                                                    'info_url': None,
#                                                    'launchers': '',
#                                                    'logo': {'credit': 'USSR',
#                                                             'id': 182,
#                                                             'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet2520space2520program_logo_20191229081307.png',
#                                                             'license': {'id': 1,
#                                                                         'link': None,
#                                                                         'name': 'Unknown',
#                                                                         'priority': 9},
#                                                             'name': 'Soviet '
#                                                                     'Space '
#                                                                     'Program '
#                                                                     'logo',
#                                                             'single_use': True,
#                                                             'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/255bauto255d__image_thumbnail_20240305185129.png',
#                                                             'variants': []},
#                                                    'name': 'Soviet Space '
#                                                            'Program',
#                                                    'parent': None,
#                                                    'pending_launches': 0,
#                                                    'response_mode': 'normal',
#                                                    'social_logo': {'credit': 'USSR',
#                                                                    'id': 92,
#                                                                    'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet_space_pr_image_20251017113333.png',
#                                                                    'license': {'id': 1,
#                                                                                'link': None,
#                                                                                'name': 'Unknown',
#                                                                                'priority': 9},
#                                                                    'name': 'Soviet '
#                                                                            'Space '
#                                                                            'Program '
#                                                                            'social '
#                                                                            'logo',
#                                                                    'single_use': True,
#                                                                    'thumbnail_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/soviet_space_pr_image_thumbnail_20251017113333.png',
#                                                                    'variants': []},
#                                                    'social_media_links': [],
#                                                    'spacecraft': '',
#                                                    'successful_landings': 0,
#                                                    'successful_landings_payload': 3,
#                                                    'successful_landings_spacecraft': 0,
#                                                    'successful_launches': 2288,
#                                                    'total_launch_count': 2456,
#                                                    'type': {'id': 1,
#                                                             'name': 'Government'},
#                                                    'url': 'https://ll.thespacedevs.com/2.3.0/agencies/66/',
#                                                    'wiki_url': 'https://en.wikipedia.org/wiki/Soviet_space_program'},
#                                       'program': [],
#                                       'response_mode': 'detailed',
#                                       'type': {'id': 4,
#                                                'name': 'Technology '
#                                                        'Demonstrator'},
#                                       'wiki_link': 'https://en.wikipedia.org/wiki/Sputnik_1'},
#                           'response_mode': 'detailed',
#                           'url': 'https://ll.thespacedevs.com/2.3.0/payload_flights/5/'}],
#             'spacecraft_stage': []},
#  'slug': 'sputnik-8k74ps-sputnik-1',
#  'status': {'abbrev': 'Success',
#             'description': 'The launch vehicle successfully inserted its '
#                            'payload(s) into the target orbit(s).',
#             'id': 3,
#             'name': 'Launch Successful'},
#  'timeline': [],
#  'updates': [],
#  'url': 'https://ll.thespacedevs.com/2.3.0/launches/e3df2ecd-c239-472f-95e4-2b89b4f75800/',
#  'vid_urls': [{'description': 'On 4 October 1957, a Sputnik 8K71PS rocket '
#                               'launched the Earth’s first artificial satellite '
#                               '- Sputnik 1. The satellite was a metal sphere '
#                               '(58 cm in diameter) ...',
#                'end_time': '2017-10-03T13:09:19Z',
#                'feature_image': 'https://i.ytimg.com/vi/DTDb3eKpPiw/maxresdefault.jpg',
#                'language': {'code': 'en', 'id': 1, 'name': 'English'},
#                'live': False,
#                'priority': 10,
#                'publisher': 'SciNews',
#                'source': 'youtube.com',
#                'start_time': '2017-10-03T13:07:12Z',
#                'title': 'Sputnik 1 - Earth’s First Artificial Satellite',
#                'type': {'id': 1, 'name': 'Official Webcast'},
#                'url': 'https://www.youtube.com/watch?v=DTDb3eKpPiw'}],
#  'weather_concerns': None,
#  'webcast_live': False,
#  'window_end': '1957-10-04T19:28:34Z',
#  'window_start': '1957-10-04T19:28:34Z'}

# %% [markdown]
# ## Testing Data Paths - doing the Mapping
# Mapping paths for 7 attributes on a single launch record before running the full loop on the sample.
#
# Used following reference for safely unnesting dictionary using .get() chaining - a little experimenting:
#
#  https://stackoverflow.com/questions/25833613/safe-method-to-get-value-of-nested-dictionary

# %%
#testing paths on the first launch record
test_launch = data_source[0]

print("Testing 'Mission' fields:")
print(f"Launch ID: {test_launch.get('id')}")
print(f"Mission Name: {test_launch.get('mission', {}).get('name')}")
print(f"Mission Type: {test_launch.get('mission', {}).get('type')}")
print(f"Orbit Name: {test_launch.get('mission', {}).get('orbit', {}).get('name')}")

print("\nTesting 'Crew/Program' field:")
print(f"Program: {test_launch.get('program')}") # shows it's a list

print("\nTesting 'Agency/LSP' fields:")
print(f"LSP Name: {test_launch.get('launch_service_provider', {}).get('name')}")
print(f"LSP Type: {test_launch.get('launch_service_provider', {}).get('type', {}).get('name')}")
# Out:
# Testing 'Mission' fields:
# Launch ID: e3df2ecd-c239-472f-95e4-2b89b4f75800
# Mission Name: Sputnik 1
# Mission Type: Test Flight
# Orbit Name: Low Earth Orbit
#
# Testing 'Crew/Program' field:
# Program: []
#
# Testing 'Agency/LSP' fields:
# LSP Name: Soviet Space Program
# LSP Type: Government

# %% [markdown]
# ## Extracting Mission Data
#
# Looping through launches to extract 10 Mission attributes into a table.
#
# Using if/else to handle missing data safely.
#
# Note: Only taking first 'program' name for testing. TODO: if we find a launch with multiple programs.

# %%
mission_table = []
mission_header = [ # column names
    "launch_id",
    "mission_id",
    "mission_name",
    "mission_type",
    "mission_description",
    "orbit_name",
    "orbit_abbrev",
    "program_name",
    "lsp_name",
    "lsp_type"
]

for launch in data_source:

    launch_id = launch.get('id') # most important attribute for merging later

    # mission and orbit data
    mission_data = launch.get('mission')
    if mission_data:
        mission_id = mission_data.get('id')
        mission_name = mission_data.get('name')
        mission_type = mission_data.get('type')
        mission_desc = mission_data.get('description')

        # orbit data nested inside mission
        orbit_data = mission_data.get('orbit')
        if orbit_data:
            orbit_name = orbit_data.get('name')
            orbit_abbrev = orbit_data.get('abbrev')
        else:
            orbit_name = None
            orbit_abbrev = None
    else:
        # handle missing Mission data
        mission_id = None
        mission_name = None
        mission_type = None
        mission_desc = None
        orbit_name = None
        orbit_abbrev = None

    # extracts program data - looking for "crewed" indicator
    # stores as a list
    program_list = launch.get('program', [])
    if program_list:
        program_name = program_list[0].get('name') # TODO: handle multiple programs
    else:
        program_name = None

    # launch service provider data - aka "agency"
    lsp_data = launch.get('launch_service_provider')
    if lsp_data:
        lsp_name = lsp_data.get('name')

        # goes one more level down for nested, nested info
        lsp_type_data = lsp_data.get('type')
        if lsp_type_data:
            lsp_type = lsp_type_data.get('name')
        else:
            lsp_type = None
    else:
        lsp_name = None
        lsp_type = None

    # builds the row for this launch
    row = [
        launch_id,
        mission_id,
        mission_name,
        mission_type,
        mission_desc,
        orbit_name,
        orbit_abbrev,
        program_name,
        lsp_name,
        lsp_type
    ]
    mission_table.append(row)

print(f"Finished processing this sample. Created table with {len(mission_table)} rows.")
# Out:
# Finished processing this sample. Created table with 7333 rows.

# %% [markdown]
# ## Creates DataFrame and Saves Output
#
# Converts mission table to a pandas DataFrame with a quick preview of DataFrame.
#
# Checks data quality with `.info()` to identify missing values.
#
# Saves as TSV instead of CSV since mission descriptions may contain commas.
#
# **Group discussion topic:** What to do with missing values? (Drop rows? Fill nulls w/ NA or 0 or unknown? Keep as is?)

# %%
# convert extracted data to DataFrame
df_mission = pd.DataFrame(mission_table, columns=mission_header)
print("Successfully created Mission DataFrame:")

# summary of categorical columns
print("\nMission Type Distribution:")
print(df_mission['mission_type'].value_counts())

print("\nLSP Type Distribution:")
print(df_mission['lsp_type'].value_counts())

# preview DataFrame
print("\nPrinting first 3 rows:")
print(df_mission.head(3)) # displays plain text with labels

# checks data types and null counts - an important cleaning step
print("\nDataFrame Info (Checking for nulls)")
df_mission.info()

# saving as TSV because mission_description might have commas
output_filename = 'clean_mission_data.tsv'
df_mission.to_csv(output_filename, sep='\t', index=False)

print(f"\nSuccessfully saved data to {output_filename}")
# Out:
# Successfully created Mission DataFrame:
#
# Mission Type Distribution:
# mission_type
# Government/Top Secret          2253
# Communications                 1568
# Earth Science                   935
# Navigation                      407
# Test Flight                     342
# Human Exploration               314
# Test Target                     205
# Astrophysics                    167
# Resupply                        124
# Lunar Exploration                88
# Robotic Exploration              88
# Dedicated Rideshare              67
# Planetary Science                59
# Technology                       43
# Heliophysics                     37
#                                  26
# Tourism                          25
# Materials Science                24
# Suborbital                       22
# Biology                          18
# Unknown                           3
# Space Situational Awareness       1
# Name: count, dtype: int64
#
# LSP Type Distribution:
# lsp_type
# Government       5307
# Commercial       1942
# Private            72
# Multinational      12
# Name: count, dtype: int64
#
# Printing first 3 rows:
#                               launch_id  mission_id mission_name mission_type  \
# 0  e3df2ecd-c239-472f-95e4-2b89b4f75800      1430.0    Sputnik 1  Test Flight
# 1  f8c9f344-a6df-4f30-873a-90fe3a7840b3      1431.0    Sputnik 2  Test Flight
# 2  535c1a09-97c8-4f96-bb64-6336d4bcb1fb      1432.0     Vanguard  Test Flight
#
#                                  mission_description       orbit_name  \
# 0  First artificial satellite consisting of a 58 ...  Low Earth Orbit
# 1  Second artificial satellite and first to carry...  Low Earth Orbit
# 2  Small satellite used to test the Vanguard thre...  Low Earth Orbit
#
#   orbit_abbrev program_name              lsp_name    lsp_type
# 0          LEO         None  Soviet Space Program  Government
# 1          LEO         None  Soviet Space Program  Government
# 2          LEO         None               US Navy  Government
#
# DataFrame Info (Checking for nulls)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7333 entries, 0 to 7332
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   launch_id            7333 non-null   object
#  1   mission_id           6816 non-null   float64
#  2   mission_name         6816 non-null   object
#  3   mission_type         6816 non-null   object
#  4   mission_description  6816 non-null   object
#  5   orbit_name           6803 non-null   object
#  6   orbit_abbrev         6803 non-null   object
#  7   program_name         1471 non-null   object
#  8   lsp_name             7333 non-null   object
#  9   lsp_type             7333 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 573.0+ KB
#
# Successfully saved data to clean_mission_data.tsv

# %% [markdown]
# ## Preview First 10 Rows
#
# Displaying direct as HTML table for better readability.

# %%
df_mission.head(10)
# Out:
#                               launch_id  mission_id  \
# 0  08fbd641-9f53-4fc8-88be-41fe7c115123        7293
# 1  3bfed6d5-d65e-4133-b51a-b664bbd9d006        6270
# 2  57b5b880-7892-42b1-a327-1c919c033cb6        7298
# 3  09678f8e-d3e5-4e26-87c1-d9b9141c1f61        7299
# 4  92ec4610-4576-4077-b538-65272a5d6491        7277
# 5  64b19cd9-9b2a-4724-890b-6a7001eb3644        7297
# 6  161ca0fe-fef2-40a3-88f8-de777c7fc895        7300
# 7  86d62815-9266-481b-951e-e53670d27341        7113
# 8  10cb03bb-53df-462f-be12-e8e4b8dcca82        7304
# 9  b563b8fa-9f6c-4883-9a89-9cb5a073864f        6997
#
#                                         mission_name           mission_type  \
# 0                               Starlink Group 17-10         Communications
# 1  Cygnus CRS-2 NG-23 (S.S. William “Willie” C. M...               Resupply
# 2                             SatNet test satellites         Communications
# 3                               Starlink Group 10-61         Communications
# 4                                              NS-35             Suborbital
# 5                               Starlink Group 17-12         Communications
# 6                               Starlink Group 10-27         Communications
# 7                                            NROL-48  Government/Top Secret
# 8                                              JENNA  Government/Top Secret
# 9                       Geely Constellation Group 06         Communications
#
#                                  mission_description       orbit_name  \
# 0  A batch of 24 satellites for the Starlink mega...  Low Earth Orbit
# 1  This is the 23rd flight of the Northrop Grumma...  Low Earth Orbit
# 2  Officially described as "Satellite-Internet Te...  Low Earth Orbit
# 3  A batch of 28 satellites for the Starlink mega...  Low Earth Orbit
# 4  NS-35 is the 35th flight for the New Shepard p...       Suborbital
# 5  A batch of 24 satellites for the Starlink mega...  Low Earth Orbit
# 6  A batch of 28 satellites for the Starlink mega...  Low Earth Orbit
# 7  Eleventh batch of satellites for a reconnaissa...          Unknown
# 8  Sub-orbital launch under Rocket Lab’s Hyperson...       Suborbital
# 9  12 LEO communications satellites for Chinese c...  Low Earth Orbit
#
#   orbit_abbrev                 program_name  \
# 0          LEO                         None
# 1          LEO  International Space Station
# 2          LEO                         None
# 3          LEO                     Starlink
# 4          Sub                         None
# 5          LEO                         None
# 6          LEO                     Starlink
# 7          N/A                         None
# 8          Sub                         None
# 9          LEO                         None
#
#                                             lsp_name    lsp_type
# 0                                             SpaceX  Commercial
# 1                                             SpaceX  Commercial
# 2  China Aerospace Science and Technology Corpora...  Government
# 3                                             SpaceX  Commercial
# 4                                        Blue Origin  Commercial
# 5                                             SpaceX  Commercial
# 6                                             SpaceX  Commercial
# 7                                             SpaceX  Commercial
# 8                                         Rocket Lab  Commercial
# 9                              China Rocket Co. Ltd.  Commercial

# %% [markdown]
# ## Next Steps
#
# Mission parameters extracted and saved as `clean_mission_data.tsv`
#
# **MISSION PARAMETERS TODOs:**
# - Merge with other team members extracted data
# - Handle launches with multiple 'programs' (currently only taking first)
# - Validate data quality across full dataset
# - Create data dictionary documenting each column
