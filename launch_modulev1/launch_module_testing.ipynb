# %% [markdown]
# # First test of the launch module

# %%
from datarequest import *

# %%
#testing fethcall 11/24/25 5:37

test_launch_df = fetchall_previous_launches(time_zone = 'America/New_York', collection_mode = 'test', verbose = True, save= False)
# Out:
# Query URL: https://ll.thespacedevs.com/2.3.0/launches/previous/?mode=detailed&limit=100&ordering=net
# Running in TEST mode
# STARTING DATA ACQUISITION
# Request #: 1
# Success! So far collected 100 total launches.
# Request #: 2
# Success! So far collected 200 total launches.
# Request #: 3
# Success! So far collected 300 total launches.
# Request #: 4
# Success! So far collected 400 total launches.
# 4 CALLS MADE. PAUSING FOR 3 MIN.
# Resuming at 05:40:46 PM EST
# RESUMING API CALLS
# Request #: 5
# Success! So far collected 500 total launches.
# Request #: 6
# Success! So far collected 600 total launches.
# Request #: 7
# Success! So far collected 700 total launches.
# Request #: 8
# Success! So far collected 800 total launches.
# 8 CALLS MADE. PAUSING FOR 3 MIN.
# Resuming at 05:44:16 PM EST
# RESUMING API CALLS
# Request #: 9
# Success! So far collected 900 total launches.
# Request #: 10
# Success! So far collected 1000 total launches.
# Request #: 11
# ...

# %%
launches_2024_2025 = launch_by_year(2024, 2025, time_zone = 'America/New_York', mode = 'test', verbose=True)
# Out:
# Query URL: https://ll.thespacedevs.com/2.3.0/launches/previous/?net__gte=2024-01-01T00:00:00&net__lte=2025-12-31T00:00:00&mode=detailed&limit=100&ordering=net
# Running in TEST mode
# STARTING DATA ACQUISITION
# Request #: 1
# Success! So far collected 100 total launches.
# Request #: 2
# Success! So far collected 200 total launches.
# Request #: 3
# Success! So far collected 300 total launches.
# Request #: 4
# Success! So far collected 400 total launches.
# 4 CALLS MADE. PAUSING FOR 3 MIN.
# Resuming at 11:34:54 PM EST
# RESUMING API CALLS
# Request #: 5
# Success! So far collected 500 total launches.
# Request #: 6
# Success! So far collected 568 total launches.
# FINISHED: Collected 568 total launches!!!

# %%
launches_2024_2025[-1]
# Out:
# {'id': '6da58dd3-57bf-4c0a-a003-c56268db3e59',
#  'url': 'https://ll.thespacedevs.com/2.3.0/launches/6da58dd3-57bf-4c0a-a003-c56268db3e59/',
#  'name': 'Long March 2F/G | Shenzhou 22',
#  'response_mode': 'detailed',
#  'slug': 'long-march-2fg-shenzhou-22',
#  'launch_designator': None,
#  'status': {'id': 3,
#   'name': 'Launch Successful',
#   'abbrev': 'Success',
#   'description': 'The launch vehicle successfully inserted its payload(s) into the target orbit(s).'},
#  'last_updated': '2025-11-25T04:34:07Z',
#  'net': '2025-11-25T04:11:45Z',
#  'net_precision': {'id': 0,
#   'name': 'Second',
#   'abbrev': 'SEC',
#   'description': 'The T-0 is accurate to the second.'},
#  'window_end': '2025-11-25T04:41:00Z',
#  'window_start': '2025-11-25T04:01:00Z',
#  'image': {'id': 1765,
#   'name': '[AUTO] Long March 2 - image',
#   'image_url': 'https://thespacedevs-prod.nyc3.digitaloceanspaces.com/media/images/long_march_2_image_20210908195835.jpeg',
# ...
